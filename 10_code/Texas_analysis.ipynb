# %%
import pandas as pd
import numpy as np
from plotnine import *

# %% [markdown]
# ### Import Dataset

# %%
mortality_state = pd.read_csv('../20_intermediate_files/mortality.csv')

# %% [markdown]
# ### Identify reference states
# Assess trends for states that are similar to the target state of Texas. <br>
# Will begin exploration with states that are geographically closer to Texas and will exapnd search in case a good match is not found.

# %%
mortality_state_subset = mortality_state[(mortality_state['State'] == 'TX') | 
                                         #(mortality_state['State'] == 'NM') | 
                                         (mortality_state['State'] == 'AZ') | 
                                         #(mortality_state['State'] == 'KS') | 
                                         (mortality_state['State'] == 'CA') | 
                                         (mortality_state['State'] == 'OK')
                                         #(mortality_state['State'] == 'AK') | 
                                         #(mortality_state['State'] == 'LA') 
                                        ]

# %%
(
ggplot(mortality_state_subset, aes(x='Year', y='Deaths', color='State')) +
geom_line(alpha = 0.5, size = 0.5)    
)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/plotnine/utils.py:1246: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
# <ggplot: (8762666590576)>

# %% [markdown]
# ### Reference States for Texas are:
# 1. Arizona <br>
# 2. California <br>
# 3. Oklahoma <br>
#
# These states exhibit the closest similar trends to the target state of Texas
